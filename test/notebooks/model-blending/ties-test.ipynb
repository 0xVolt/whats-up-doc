# %% [markdown]
# <a href="https://colab.research.google.com/github/0xVolt/whats-up-doc/blob/main/test/notebooks/model-blending/blend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Merging CodeLLMs to Create an Efficant Low-Memory Quantized Model for `whats-up-doc` using the TIES Method
#
# ## Download and Install `mergekit`

# %%
import os

dirName = "mergekit"
cwd = os.getcwd()

concatDirPath = os.path.join(cwd, dirName)

if not os.path.exists(concatDirPath):
    # !git clone https://github.com/cg123/mergekit.git
    # !cd mergekit && pip install -q -e .
# Out:
# Cloning into 'mergekit'...
# remote: Enumerating objects: 2265, done.
# remote: Counting objects: 100% (1340/1340), done.
# remote: Compressing objects: 100% (514/514), done.
# remote: Total 2265 (delta 1068), reused 939 (delta 825), pack-reused 925
# Receiving objects: 100% (2265/2265), 638.44 KiB | 16.80 MiB/s, done.
# Resolving deltas: 100% (1584/1584), done.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.9.3 requires keras-core, which is not installed.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.6 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Create the YAML Config File to Merge Models with SLERP

# %%
import os
import yaml
from transformers import AutoModelWithLMHead, AutoTokenizer, pipeline

# %% [markdown]
# ### Write Config Script

# %%
# Set the resultant model's name
MODEL_NAME = 'whats-up-llamas-ties'

MODEL_1 = "meta-llama/Meta-Llama-3-8B-Instruct"
MODEL_2 = "codellama/CodeLlama-7b-Instruct-hf"

OUTPUT_DIR = "whats-up-llamas-ties"

# %% [markdown]
# #### TIES YAML Config Creation

# %%
yamlConfigTIESLlamas = f"""
models:
  - model: {MODEL_1}  # no parameters necessary for base model
  - model: {MODEL_2}
    parameters:
      density: 0.5
      weight: 0.5
merge_method: ties
base_model: {MODEL_1}
parameters:
  normalize: true
  int8_mask: true
dtype: float16

"""

# %% [markdown]
# ### Save Config Script

# %%
# Save the YAML configuration to a file
yamlFileName = "config.yaml"
with open(yamlFileName, "w") as f:
    f.write(yamlConfigTIESLlamas)

# %% [markdown]
# ## Merge Models

# %%
cmd = f"mergekit-yaml {yamlFileName} {OUTPUT_DIR} --allow-crimes --copy-tokenizer --out-shard-size 1B --low-cpu-memory --write-model-card --lazy-unpickle"
# !{cmd}
# Out:
# config.json: 100%|█████████████████████████████| 646/646 [00:00<00:00, 4.46MB/s]
# config.json: 100%|█████████████████████████████| 654/654 [00:00<00:00, 4.63MB/s]
# Warmup loader cache:   0%|                                | 0/2 [00:00<?, ?it/s]
# Fetching 10 files:   0%|                                 | 0/10 [00:00<?, ?it/s]
#
# tokenizer.json:   0%|                               | 0.00/1.84M [00:00<?, ?B/s]
#
#
# model-00002-of-00002.safetensors:   0%|             | 0.00/3.50G [00:00<?, ?B/s]
#
#
#
# pytorch_model.bin.index.json: 100%|████████| 23.9k/23.9k [00:00<00:00, 68.2MB/s]
#
#
#
#
# model.safetensors.index.json: 100%|████████| 25.1k/25.1k [00:00<00:00, 83.8MB/s]
#
#
#
#
# special_tokens_map.json: 100%|█████████████████| 411/411 [00:00<00:00, 2.52MB/s]
#
#
#
#
# generation_config.json: 100%|███████████████████| 116/116 [00:00<00:00, 544kB/s]
#
# Fetching 10 files:  20%|█████                    | 2/10 [00:00<00:01,  6.49it/s]
#
#
# model-00002-of-00002.safetensors:   0%|     | 10.5M/3.50G [00:00<00:34, 100MB/s]
#
#
#
# model-00001-of-00002.safetensors:   0%|             | 0.00/9.98G [00:00<?, ?B/s]
#
# tokenizer.json: 100%|██████████████████████| 1.84M/1.84M [00:00<00:00, 15.4MB/s]
#
#
# tokenizer_config.json: 100%|███████████████| 1.59k/1.59k [00:00<00:00, 8.54MB/s]
#
#
#
# model-00002-of-00002.safetensors:   1%|     | 41.9M/3.50G [00:00<00:18, 183MB/s]
#
#
#
# model-00001-of-00002.safetensors:   0%|    | 10.5M/9.98G [00:00<02:59, 55.6MB/s]
#
# tokenizer.model: 100%|███████████████████████| 500k/500k [00:00<00:00, 8.25MB/s]
#
#
#
# model-00002-of-00002.safetensors:   2%|     | 73.4M/3.50G [00:00<00:16, 206MB/s]
#
#
#
# model-00001-of-00002.safetensors:   0%|     | 31.5M/9.98G [00:00<01:29, 111MB/s]
#
#
# model-00002-of-00002.safetensors:   3%|▏     | 105M/3.50G [00:00<00:15, 220MB/s]
#
#
#
# model-00001-of-00002.safetensors:   1%|     | 62.9M/9.98G [00:00<01:02, 160MB/s]
#
#
# model-00002-of-00002.safetensors:   4%|▏     | 136M/3.50G [00:00<00:14, 227MB/s]
#
#
#
# model-00001-of-00002.safetensors:   1%|     | 94.4M/9.98G [00:00<00:54, 182MB/s]
#
#
# model-00002-of-00002.safetensors:   5%|▎     | 168M/3.50G [00:00<00:14, 234MB/s]
#
#
#
# model-00001-of-00002.safetensors:   1%|      | 126M/9.98G [00:00<00:47, 206MB/s]
#
#
# model-00002-of-00002.safetensors:   6%|▎     | 199M/3.50G [00:00<00:13, 239MB/s]
#
#
#
# model-00001-of-00002.safetensors:   2%|      | 157M/9.98G [00:00<00:44, 221MB/s]
#
#
# model-00002-of-00002.safetensors:   7%|▍     | 231M/3.50G [00:01<00:13, 244MB/s]
#
#
#
# model-00001-of-00002.safetensors:   2%|      | 189M/9.98G [00:00<00:42, 232MB/s]
#
#
# model-00002-of-00002.safetensors:   7%|▍     | 262M/3.50G [00:01<00:13, 246MB/s]
#
#
#
# model-00001-of-00002.safetensors:   2%|▏     | 220M/9.98G [00:01<00:40, 238MB/s]
#
#
# model-00002-of-00002.safetensors:   8%|▌     | 294M/3.50G [00:01<00:12, 247MB/s]
#
#
#
# model-00001-of-00002.safetensors:   3%|▏     | 252M/9.98G [00:01<00:39, 244MB/s]
#
#
# model-00002-of-00002.safetensors:   9%|▌     | 325M/3.50G [00:01<00:12, 248MB/s]
#
#
#
# model-00001-of-00002.safetensors:   3%|▏     | 283M/9.98G [00:01<00:38, 252MB/s]
#
#
# model-00002-of-00002.safetensors:  10%|▌     | 357M/3.50G [00:01<00:12, 252MB/s]
#
#
#
# model-00001-of-00002.safetensors:   3%|▏     | 315M/9.98G [00:01<00:37, 254MB/s]
#
#
# model-00002-of-00002.safetensors:  11%|▋     | 388M/3.50G [00:01<00:12, 252MB/s]
#
#
#
# model-00001-of-00002.safetensors:   3%|▏     | 346M/9.98G [00:01<00:38, 253MB/s]
#
#
# model-00002-of-00002.safetensors:  12%|▋     | 419M/3.50G [00:01<00:12, 253MB/s]
#
#
#
# model-00001-of-00002.safetensors:   4%|▏     | 377M/9.98G [00:01<00:37, 254MB/s]
#
#
# model-00002-of-00002.safetensors:  13%|▊     | 451M/3.50G [00:01<00:11, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:   4%|▏     | 409M/9.98G [00:01<00:38, 251MB/s]
#
#
# model-00002-of-00002.safetensors:  14%|▊     | 482M/3.50G [00:02<00:11, 254MB/s]
#
#
#
# model-00001-of-00002.safetensors:   4%|▎     | 440M/9.98G [00:01<00:37, 251MB/s]
#
#
# model-00002-of-00002.safetensors:  15%|▉     | 514M/3.50G [00:02<00:11, 252MB/s]
#
#
#
# model-00001-of-00002.safetensors:   5%|▎     | 472M/9.98G [00:02<00:37, 251MB/s]
#
#
# model-00002-of-00002.safetensors:  16%|▉     | 545M/3.50G [00:02<00:11, 252MB/s]
#
#
#
# model-00001-of-00002.safetensors:   5%|▎     | 503M/9.98G [00:02<00:36, 256MB/s]
#
#
# model-00002-of-00002.safetensors:  16%|▉     | 577M/3.50G [00:02<00:11, 256MB/s]
#
#
#
# model-00001-of-00002.safetensors:   5%|▎     | 535M/9.98G [00:02<00:36, 259MB/s]
#
#
# model-00002-of-00002.safetensors:  17%|█     | 608M/3.50G [00:02<00:11, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:   6%|▎     | 566M/9.98G [00:02<00:36, 261MB/s]
#
#
# model-00002-of-00002.safetensors:  18%|█     | 640M/3.50G [00:02<00:10, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:   6%|▎     | 598M/9.98G [00:02<00:35, 263MB/s]
#
#
# model-00002-of-00002.safetensors:  19%|█▏    | 671M/3.50G [00:02<00:10, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:   6%|▍     | 629M/9.98G [00:02<00:35, 265MB/s]
#
#
# model-00002-of-00002.safetensors:  20%|█▏    | 703M/3.50G [00:02<00:10, 266MB/s]
#
#
#
# model-00001-of-00002.safetensors:   7%|▍     | 661M/9.98G [00:02<00:35, 266MB/s]
#
#
# model-00002-of-00002.safetensors:  21%|█▎    | 734M/3.50G [00:02<00:10, 267MB/s]
#
#
#
# model-00001-of-00002.safetensors:   7%|▍     | 692M/9.98G [00:02<00:34, 267MB/s]
#
#
# model-00002-of-00002.safetensors:  22%|█▎    | 765M/3.50G [00:03<00:10, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:   7%|▍     | 724M/9.98G [00:03<00:35, 263MB/s]
#
#
# model-00002-of-00002.safetensors:  23%|█▎    | 797M/3.50G [00:03<00:10, 256MB/s]
#
#
#
# model-00001-of-00002.safetensors:   8%|▍     | 755M/9.98G [00:03<00:35, 258MB/s]
#
#
# model-00002-of-00002.safetensors:  24%|█▍    | 828M/3.50G [00:03<00:10, 258MB/s]
#
#
#
# model-00001-of-00002.safetensors:   8%|▍     | 786M/9.98G [00:03<00:35, 258MB/s]
#
#
# model-00002-of-00002.safetensors:  25%|█▍    | 860M/3.50G [00:03<00:10, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:   8%|▍     | 818M/9.98G [00:03<00:35, 259MB/s]
#
#
# model-00002-of-00002.safetensors:  25%|█▌    | 891M/3.50G [00:03<00:10, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:   9%|▌     | 849M/9.98G [00:03<00:34, 261MB/s]
#
#
# model-00002-of-00002.safetensors:  26%|█▌    | 923M/3.50G [00:03<00:09, 263MB/s]
#
#
#
# model-00001-of-00002.safetensors:   9%|▌     | 881M/9.98G [00:03<00:34, 263MB/s]
#
#
# model-00002-of-00002.safetensors:  27%|█▋    | 954M/3.50G [00:03<00:09, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:   9%|▌     | 912M/9.98G [00:03<00:34, 265MB/s]
#
#
# model-00002-of-00002.safetensors:  28%|█▋    | 986M/3.50G [00:03<00:09, 266MB/s]
#
#
#
# model-00001-of-00002.safetensors:   9%|▌     | 944M/9.98G [00:03<00:34, 265MB/s]
#
#
# model-00002-of-00002.safetensors:  29%|█▍   | 1.02G/3.50G [00:04<00:09, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  10%|▌     | 975M/9.98G [00:03<00:34, 264MB/s]
#
#
# model-00002-of-00002.safetensors:  30%|█▍   | 1.05G/3.50G [00:04<00:09, 263MB/s]
#
#
#
# model-00001-of-00002.safetensors:  10%|▌    | 1.01G/9.98G [00:04<00:34, 263MB/s]
#
#
# model-00002-of-00002.safetensors:  31%|█▌   | 1.08G/3.50G [00:04<00:09, 263MB/s]
#
#
#
# model-00001-of-00002.safetensors:  10%|▌    | 1.04G/9.98G [00:04<00:34, 262MB/s]
#
#
# model-00002-of-00002.safetensors:  32%|█▌   | 1.11G/3.50G [00:04<00:09, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:  11%|▌    | 1.07G/9.98G [00:04<00:34, 255MB/s]
#
#
# model-00002-of-00002.safetensors:  33%|█▋   | 1.14G/3.50G [00:04<00:09, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  11%|▌    | 1.10G/9.98G [00:04<00:34, 256MB/s]
#
#
# model-00002-of-00002.safetensors:  34%|█▋   | 1.17G/3.50G [00:04<00:09, 254MB/s]
#
#
#
# model-00001-of-00002.safetensors:  11%|▌    | 1.13G/9.98G [00:04<00:34, 256MB/s]
#
#
# model-00002-of-00002.safetensors:  34%|█▋   | 1.21G/3.50G [00:04<00:08, 256MB/s]
#
#
#
# model-00001-of-00002.safetensors:  12%|▌    | 1.16G/9.98G [00:04<00:34, 257MB/s]
#
#
# model-00002-of-00002.safetensors:  35%|█▊   | 1.24G/3.50G [00:04<00:08, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  12%|▌    | 1.20G/9.98G [00:04<00:34, 258MB/s]
#
#
# model-00002-of-00002.safetensors:  36%|█▊   | 1.27G/3.50G [00:05<00:08, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  12%|▌    | 1.23G/9.98G [00:04<00:33, 259MB/s]
#
#
# model-00002-of-00002.safetensors:  37%|█▊   | 1.30G/3.50G [00:05<00:08, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:  13%|▋    | 1.26G/9.98G [00:05<00:33, 259MB/s]
#
#
# model-00002-of-00002.safetensors:  38%|█▉   | 1.33G/3.50G [00:05<00:08, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:  13%|▋    | 1.29G/9.98G [00:05<00:33, 259MB/s]
#
#
# model-00002-of-00002.safetensors:  39%|█▉   | 1.36G/3.50G [00:05<00:08, 260MB/s]
#
#
#
# model-00001-of-00002.safetensors:  13%|▋    | 1.32G/9.98G [00:05<00:33, 260MB/s]
#
#
# model-00002-of-00002.safetensors:  40%|█▉   | 1.39G/3.50G [00:05<00:08, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  14%|▋    | 1.35G/9.98G [00:05<00:33, 261MB/s]
#
#
# model-00002-of-00002.safetensors:  41%|██   | 1.43G/3.50G [00:05<00:07, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  14%|▋    | 1.38G/9.98G [00:05<00:33, 260MB/s]
#
#
# model-00002-of-00002.safetensors:  42%|██   | 1.46G/3.50G [00:05<00:07, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:  14%|▋    | 1.42G/9.98G [00:05<00:33, 259MB/s]
#
#
# model-00002-of-00002.safetensors:  43%|██▏  | 1.49G/3.50G [00:05<00:07, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  15%|▋    | 1.45G/9.98G [00:05<00:33, 256MB/s]
#
#
# model-00002-of-00002.safetensors:  43%|██▏  | 1.52G/3.50G [00:06<00:07, 258MB/s]
#
#
#
# model-00001-of-00002.safetensors:  15%|▋    | 1.48G/9.98G [00:05<00:32, 258MB/s]
#
#
# model-00002-of-00002.safetensors:  44%|██▏  | 1.55G/3.50G [00:06<00:07, 258MB/s]
#
#
#
# model-00001-of-00002.safetensors:  15%|▊    | 1.51G/9.98G [00:06<00:32, 258MB/s]
#
#
# model-00002-of-00002.safetensors:  45%|██▎  | 1.58G/3.50G [00:06<00:07, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  15%|▊    | 1.54G/9.98G [00:06<00:32, 260MB/s]
#
#
# model-00002-of-00002.safetensors:  46%|██▎  | 1.61G/3.50G [00:06<00:07, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:  16%|▊    | 1.57G/9.98G [00:06<00:33, 252MB/s]
#
#
# model-00002-of-00002.safetensors:  47%|██▎  | 1.65G/3.50G [00:06<00:07, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  16%|▊    | 1.60G/9.98G [00:06<00:34, 245MB/s]
#
#
# model-00002-of-00002.safetensors:  48%|██▍  | 1.68G/3.50G [00:06<00:07, 250MB/s]
#
#
#
# model-00001-of-00002.safetensors:  16%|▊    | 1.64G/9.98G [00:06<00:34, 242MB/s]
#
#
# model-00002-of-00002.safetensors:  49%|██▍  | 1.71G/3.50G [00:06<00:07, 242MB/s]
#
#
#
# model-00001-of-00002.safetensors:  17%|▊    | 1.67G/9.98G [00:06<00:34, 238MB/s]
#
#
# model-00002-of-00002.safetensors:  50%|██▍  | 1.74G/3.50G [00:06<00:07, 237MB/s]
#
#
#
# model-00001-of-00002.safetensors:  17%|▊    | 1.70G/9.98G [00:06<00:34, 237MB/s]
#
#
# model-00002-of-00002.safetensors:  51%|██▌  | 1.77G/3.50G [00:07<00:07, 232MB/s]
#
#
#
# model-00001-of-00002.safetensors:  17%|▊    | 1.73G/9.98G [00:06<00:34, 237MB/s]
#
#
# model-00002-of-00002.safetensors:  52%|██▌  | 1.80G/3.50G [00:07<00:07, 234MB/s]
#
#
#
# model-00001-of-00002.safetensors:  18%|▉    | 1.76G/9.98G [00:07<00:34, 236MB/s]
#
#
# model-00002-of-00002.safetensors:  52%|██▌  | 1.84G/3.50G [00:07<00:07, 234MB/s]
#
#
#
# model-00001-of-00002.safetensors:  18%|▉    | 1.79G/9.98G [00:07<00:34, 237MB/s]
#
#
# model-00002-of-00002.safetensors:  53%|██▋  | 1.87G/3.50G [00:07<00:06, 237MB/s]
#
#
#
# model-00001-of-00002.safetensors:  18%|▉    | 1.82G/9.98G [00:07<00:34, 238MB/s]
#
#
# model-00002-of-00002.safetensors:  54%|██▋  | 1.90G/3.50G [00:07<00:06, 239MB/s]
#
#
#
# model-00001-of-00002.safetensors:  19%|▉    | 1.86G/9.98G [00:07<00:34, 235MB/s]
#
#
# model-00002-of-00002.safetensors:  55%|██▊  | 1.93G/3.50G [00:07<00:06, 234MB/s]
#
#
#
# model-00001-of-00002.safetensors:  19%|▉    | 1.89G/9.98G [00:07<00:35, 229MB/s]
#
#
# model-00002-of-00002.safetensors:  56%|██▊  | 1.96G/3.50G [00:07<00:06, 233MB/s]
#
#
#
# model-00001-of-00002.safetensors:  19%|▉    | 1.92G/9.98G [00:07<00:34, 231MB/s]
#
#
# model-00002-of-00002.safetensors:  57%|██▊  | 1.99G/3.50G [00:07<00:06, 229MB/s]
#
#
#
# model-00001-of-00002.safetensors:  20%|▉    | 1.95G/9.98G [00:07<00:34, 234MB/s]
#
#
# model-00002-of-00002.safetensors:  58%|██▉  | 2.02G/3.50G [00:08<00:06, 233MB/s]
#
#
#
# model-00001-of-00002.safetensors:  20%|▉    | 1.98G/9.98G [00:08<00:34, 234MB/s]
#
#
# model-00002-of-00002.safetensors:  59%|██▉  | 2.06G/3.50G [00:08<00:06, 235MB/s]
#
#
#
# model-00001-of-00002.safetensors:  20%|█    | 2.01G/9.98G [00:08<00:34, 233MB/s]
#
#
# model-00002-of-00002.safetensors:  60%|██▉  | 2.09G/3.50G [00:08<00:06, 234MB/s]
#
#
#
# model-00001-of-00002.safetensors:  20%|█    | 2.04G/9.98G [00:08<00:33, 236MB/s]
#
#
# model-00002-of-00002.safetensors:  61%|███  | 2.12G/3.50G [00:08<00:05, 236MB/s]
#
#
#
# model-00001-of-00002.safetensors:  21%|█    | 2.08G/9.98G [00:08<00:33, 235MB/s]
#
#
# model-00002-of-00002.safetensors:  61%|███  | 2.15G/3.50G [00:08<00:05, 236MB/s]
#
#
#
# model-00001-of-00002.safetensors:  21%|█    | 2.11G/9.98G [00:08<00:34, 231MB/s]
#
#
# model-00002-of-00002.safetensors:  62%|███  | 2.18G/3.50G [00:08<00:05, 238MB/s]
#
#
#
# model-00001-of-00002.safetensors:  21%|█    | 2.14G/9.98G [00:08<00:33, 231MB/s]
#
#
# model-00002-of-00002.safetensors:  63%|███▏ | 2.21G/3.50G [00:08<00:05, 238MB/s]
#
#
#
# model-00001-of-00002.safetensors:  22%|█    | 2.17G/9.98G [00:08<00:33, 232MB/s]
#
#
# model-00002-of-00002.safetensors:  64%|███▏ | 2.24G/3.50G [00:09<00:05, 237MB/s]
#
#
#
# model-00001-of-00002.safetensors:  22%|█    | 2.20G/9.98G [00:09<00:33, 235MB/s]
#
#
# model-00002-of-00002.safetensors:  65%|███▎ | 2.28G/3.50G [00:09<00:05, 241MB/s]
#
#
#
# model-00001-of-00002.safetensors:  22%|█    | 2.23G/9.98G [00:09<00:32, 240MB/s]
#
#
# model-00002-of-00002.safetensors:  66%|███▎ | 2.31G/3.50G [00:09<00:04, 244MB/s]
#
#
#
# model-00001-of-00002.safetensors:  23%|█▏   | 2.26G/9.98G [00:09<00:31, 242MB/s]
#
#
# model-00002-of-00002.safetensors:  67%|███▎ | 2.34G/3.50G [00:09<00:04, 244MB/s]
#
#
#
# model-00001-of-00002.safetensors:  23%|█▏   | 2.30G/9.98G [00:09<00:31, 243MB/s]
#
#
# model-00002-of-00002.safetensors:  68%|███▍ | 2.37G/3.50G [00:09<00:04, 244MB/s]
#
#
#
# model-00001-of-00002.safetensors:  23%|█▏   | 2.33G/9.98G [00:09<00:32, 238MB/s]
#
#
# model-00002-of-00002.safetensors:  69%|███▍ | 2.40G/3.50G [00:09<00:04, 245MB/s]
#
#
#
# model-00001-of-00002.safetensors:  24%|█▏   | 2.36G/9.98G [00:09<00:31, 245MB/s]
#
#
# model-00002-of-00002.safetensors:  69%|███▍ | 2.43G/3.50G [00:09<00:04, 251MB/s]
#
#
#
# model-00001-of-00002.safetensors:  24%|█▏   | 2.39G/9.98G [00:09<00:30, 250MB/s]
#
#
# model-00002-of-00002.safetensors:  70%|███▌ | 2.46G/3.50G [00:09<00:04, 254MB/s]
#
#
#
# model-00001-of-00002.safetensors:  24%|█▏   | 2.42G/9.98G [00:09<00:29, 254MB/s]
#
#
# model-00002-of-00002.safetensors:  71%|███▌ | 2.50G/3.50G [00:10<00:04, 250MB/s]
#
#
#
# model-00001-of-00002.safetensors:  25%|█▏   | 2.45G/9.98G [00:10<00:29, 251MB/s]
#
#
# model-00002-of-00002.safetensors:  72%|███▌ | 2.53G/3.50G [00:10<00:03, 249MB/s]
#
#
# model-00002-of-00002.safetensors:  73%|███▋ | 2.56G/3.50G [00:10<00:03, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  25%|█▏   | 2.49G/9.98G [00:10<00:36, 203MB/s]
#
#
# model-00002-of-00002.safetensors:  74%|███▋ | 2.59G/3.50G [00:10<00:03, 255MB/s]
#
#
# model-00002-of-00002.safetensors:  75%|███▋ | 2.62G/3.50G [00:10<00:04, 219MB/s]
#
#
#
# model-00001-of-00002.safetensors:  25%|█▎   | 2.52G/9.98G [00:10<00:52, 143MB/s]
#
#
# model-00002-of-00002.safetensors:  76%|███▊ | 2.65G/3.50G [00:10<00:04, 193MB/s]
#
#
#
# model-00001-of-00002.safetensors:  25%|█▎   | 2.54G/9.98G [00:10<00:59, 125MB/s]
#
#
# model-00002-of-00002.safetensors:  76%|███▊ | 2.67G/3.50G [00:10<00:04, 177MB/s]
#
#
# model-00002-of-00002.safetensors:  77%|███▊ | 2.69G/3.50G [00:11<00:04, 164MB/s]
#
#
#
# model-00001-of-00002.safetensors:  26%|█▎   | 2.56G/9.98G [00:11<01:04, 114MB/s]
#
#
# model-00002-of-00002.safetensors:  78%|███▉ | 2.72G/3.50G [00:11<00:05, 150MB/s]
#
#
#
# model-00001-of-00002.safetensors:  26%|█▎   | 2.58G/9.98G [00:11<01:08, 108MB/s]
#
#
# model-00002-of-00002.safetensors:  78%|███▉ | 2.74G/3.50G [00:11<00:05, 135MB/s]
#
#
#
# model-00001-of-00002.safetensors:  26%|█▎   | 2.60G/9.98G [00:11<01:08, 107MB/s]
#
#
# model-00002-of-00002.safetensors:  79%|███▉ | 2.76G/3.50G [00:11<00:06, 118MB/s]
#
#
#
# model-00001-of-00002.safetensors:  26%|█▎   | 2.62G/9.98G [00:11<01:01, 119MB/s]
#
#
#
# model-00001-of-00002.safetensors:  26%|█▎   | 2.64G/9.98G [00:11<01:00, 120MB/s]
#
#
# model-00002-of-00002.safetensors:  79%|███▏| 2.78G/3.50G [00:12<00:07, 99.9MB/s]
#
#
#
# model-00001-of-00002.safetensors:  27%|█▎   | 2.66G/9.98G [00:12<01:08, 107MB/s]
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.68G/9.98G [00:12<01:16, 94.8MB/s]
#
#
# model-00002-of-00002.safetensors:  80%|███▏| 2.80G/3.50G [00:12<00:09, 73.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.69G/9.98G [00:12<01:33, 77.7MB/s]
#
#
# model-00002-of-00002.safetensors:  80%|███▏| 2.81G/3.50G [00:12<00:10, 66.2MB/s]
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.71G/9.98G [00:12<01:44, 69.4MB/s]
#
#
# model-00002-of-00002.safetensors:  81%|███▏| 2.82G/3.50G [00:12<00:11, 61.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.72G/9.98G [00:13<01:53, 64.1MB/s]
#
#
# model-00002-of-00002.safetensors:  81%|███▏| 2.83G/3.50G [00:13<00:11, 59.0MB/s]
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.73G/9.98G [00:13<01:57, 61.5MB/s]
#
#
# model-00002-of-00002.safetensors:  81%|███▏| 2.84G/3.50G [00:13<00:11, 57.9MB/s]
#
#
#
# model-00001-of-00002.safetensors:  27%|█   | 2.74G/9.98G [00:13<01:54, 63.0MB/s]
#
#
# model-00002-of-00002.safetensors:  82%|███▎| 2.86G/3.50G [00:13<00:09, 70.8MB/s]
#
#
#
# model-00001-of-00002.safetensors:  28%|█   | 2.75G/9.98G [00:13<01:42, 70.3MB/s]
#
#
# model-00002-of-00002.safetensors:  82%|███▎| 2.88G/3.50G [00:13<00:07, 84.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:  28%|█   | 2.77G/9.98G [00:13<01:20, 89.0MB/s]
#
#
# model-00002-of-00002.safetensors:  83%|████▏| 2.90G/3.50G [00:13<00:05, 101MB/s]
#
#
#
# model-00001-of-00002.safetensors:  28%|█   | 2.78G/9.98G [00:13<01:22, 86.8MB/s]
#
#
# model-00002-of-00002.safetensors:  84%|████▏| 2.93G/3.50G [00:13<00:04, 117MB/s]
#
#
#
# model-00001-of-00002.safetensors:  28%|█   | 2.80G/9.98G [00:13<01:17, 92.3MB/s]
#
#
# model-00002-of-00002.safetensors:  84%|████▏| 2.95G/3.50G [00:14<00:04, 124MB/s]
#
#
# model-00002-of-00002.safetensors:  85%|████▏| 2.97G/3.50G [00:14<00:04, 132MB/s]
#
#
#
# model-00001-of-00002.safetensors:  28%|█▏  | 2.82G/9.98G [00:14<01:17, 92.0MB/s]
#
#
# model-00002-of-00002.safetensors:  85%|████▎| 2.99G/3.50G [00:14<00:03, 134MB/s]
#
#
#
# model-00001-of-00002.safetensors:  28%|█▏  | 2.83G/9.98G [00:14<01:18, 90.7MB/s]
#
#
# model-00002-of-00002.safetensors:  86%|████▎| 3.01G/3.50G [00:14<00:03, 140MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.85G/9.98G [00:14<01:14, 96.2MB/s]
#
#
# model-00002-of-00002.safetensors:  87%|████▎| 3.03G/3.50G [00:14<00:03, 141MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.86G/9.98G [00:14<01:15, 93.9MB/s]
#
#
# model-00002-of-00002.safetensors:  87%|████▎| 3.05G/3.50G [00:14<00:02, 153MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.87G/9.98G [00:14<01:20, 88.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.88G/9.98G [00:14<01:25, 82.7MB/s]
#
#
# model-00002-of-00002.safetensors:  88%|████▍| 3.07G/3.50G [00:15<00:03, 114MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.89G/9.98G [00:15<01:31, 77.6MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.90G/9.98G [00:15<01:40, 70.4MB/s]
#
#
# model-00002-of-00002.safetensors:  88%|███▌| 3.09G/3.50G [00:15<00:04, 84.1MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.92G/9.98G [00:15<01:53, 62.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.93G/9.98G [00:15<01:49, 64.4MB/s]
#
#
# model-00002-of-00002.safetensors:  89%|███▌| 3.11G/3.50G [00:15<00:04, 78.8MB/s]
#
#
#
# model-00001-of-00002.safetensors:  29%|█▏  | 2.94G/9.98G [00:15<01:39, 71.0MB/s]
#
#
# model-00002-of-00002.safetensors:  89%|███▌| 3.12G/3.50G [00:15<00:04, 81.0MB/s]
#
#
#
# model-00001-of-00002.safetensors:  30%|█▏  | 2.95G/9.98G [00:15<01:30, 77.8MB/s]
#
#
# model-00002-of-00002.safetensors:  90%|███▌| 3.15G/3.50G [00:16<00:04, 88.6MB/s]
#
#
#
# model-00001-of-00002.safetensors:  30%|█▏  | 2.97G/9.98G [00:16<01:17, 90.1MB/s]
#
#
# model-00002-of-00002.safetensors:  90%|███▌| 3.17G/3.50G [00:16<00:03, 97.3MB/s]
#
#
#
# model-00001-of-00002.safetensors:  30%|█▍   | 2.99G/9.98G [00:16<01:09, 100MB/s]
#
#
# model-00002-of-00002.safetensors:  91%|████▌| 3.19G/3.50G [00:16<00:02, 105MB/s]
#
#
#
# model-00001-of-00002.safetensors:  30%|█▌   | 3.01G/9.98G [00:16<01:04, 108MB/s]
#
#
# model-00002-of-00002.safetensors:  92%|████▌| 3.21G/3.50G [00:16<00:02, 113MB/s]
#
#
#
# model-00001-of-00002.safetensors:  30%|█▌   | 3.03G/9.98G [00:16<00:59, 117MB/s]
#
#
# model-00002-of-00002.safetensors:  92%|████▌| 3.23G/3.50G [00:16<00:02, 119MB/s]
#
#
#
# model-00001-of-00002.safetensors:  31%|█▌   | 3.05G/9.98G [00:16<00:55, 124MB/s]
#
#
# model-00002-of-00002.safetensors:  93%|████▋| 3.25G/3.50G [00:16<00:01, 125MB/s]
#
#
#
# model-00001-of-00002.safetensors:  31%|█▌   | 3.07G/9.98G [00:16<00:53, 128MB/s]
#
#
# model-00002-of-00002.safetensors:  93%|████▋| 3.27G/3.50G [00:17<00:01, 132MB/s]
#
#
#
# model-00001-of-00002.safetensors:  31%|█▌   | 3.09G/9.98G [00:16<00:52, 132MB/s]
#
#
# model-00002-of-00002.safetensors:  94%|████▋| 3.29G/3.50G [00:17<00:01, 134MB/s]
#
#
#
# model-00001-of-00002.safetensors:  31%|█▌   | 3.11G/9.98G [00:17<00:50, 137MB/s]
#
#
# model-00002-of-00002.safetensors:  95%|████▋| 3.31G/3.50G [00:17<00:01, 138MB/s]
#
#
#
# model-00001-of-00002.safetensors:  31%|█▌   | 3.14G/9.98G [00:17<00:48, 140MB/s]
#
#
# model-00002-of-00002.safetensors:  95%|████▊| 3.33G/3.50G [00:17<00:01, 143MB/s]
#
#
#
# model-00001-of-00002.safetensors:  32%|█▌   | 3.16G/9.98G [00:17<00:47, 145MB/s]
#
#
# model-00002-of-00002.safetensors:  96%|████▊| 3.36G/3.50G [00:17<00:00, 150MB/s]
#
#
#
# model-00001-of-00002.safetensors:  32%|█▌   | 3.18G/9.98G [00:17<00:45, 149MB/s]
#
#
# model-00002-of-00002.safetensors:  96%|████▊| 3.38G/3.50G [00:17<00:00, 150MB/s]
#
#
#
# model-00001-of-00002.safetensors:  32%|█▌   | 3.20G/9.98G [00:17<00:44, 154MB/s]
#
#
# model-00002-of-00002.safetensors:  97%|████▊| 3.40G/3.50G [00:17<00:00, 154MB/s]
#
#
#
# model-00001-of-00002.safetensors:  32%|█▌   | 3.22G/9.98G [00:17<00:43, 154MB/s]
#
#
# model-00002-of-00002.safetensors:  98%|████▉| 3.42G/3.50G [00:17<00:00, 155MB/s]
#
#
#
# model-00001-of-00002.safetensors:  32%|█▌   | 3.24G/9.98G [00:17<00:43, 156MB/s]
#
#
# model-00002-of-00002.safetensors:  98%|████▉| 3.44G/3.50G [00:18<00:00, 157MB/s]
#
#
#
# model-00001-of-00002.safetensors:  33%|█▋   | 3.26G/9.98G [00:18<00:43, 155MB/s]
#
#
# model-00002-of-00002.safetensors:  99%|████▉| 3.46G/3.50G [00:18<00:00, 156MB/s]
#
#
#
# model-00001-of-00002.safetensors:  33%|█▋   | 3.28G/9.98G [00:18<00:42, 157MB/s]
#
#
# model-00002-of-00002.safetensors:  99%|████▉| 3.48G/3.50G [00:18<00:00, 159MB/s]
#
#
#
# model-00001-of-00002.safetensors:  33%|█▋   | 3.30G/9.98G [00:18<00:40, 166MB/s]
#
#
# model-00002-of-00002.safetensors: 100%|█████| 3.50G/3.50G [00:18<00:00, 155MB/s]
#
#
#
# model-00002-of-00002.safetensors: 100%|█████| 3.50G/3.50G [00:18<00:00, 189MB/s]
#
#
#
#
# model-00001-of-00002.safetensors:  34%|█▋   | 3.34G/9.98G [00:18<00:42, 157MB/s]
#
#
#
# model-00001-of-00002.safetensors:  34%|█▋   | 3.37G/9.98G [00:18<00:40, 162MB/s]
#
#
#
# model-00001-of-00002.safetensors:  34%|█▋   | 3.40G/9.98G [00:18<00:37, 174MB/s]
#
#
#
# model-00001-of-00002.safetensors:  34%|█▋   | 3.42G/9.98G [00:18<00:36, 180MB/s]
#
#
#
# model-00001-of-00002.safetensors:  35%|█▋   | 3.45G/9.98G [00:19<00:33, 194MB/s]
#
#
#
# model-00001-of-00002.safetensors:  35%|█▋   | 3.48G/9.98G [00:19<00:30, 214MB/s]
#
#
#
# model-00001-of-00002.safetensors:  35%|█▊   | 3.51G/9.98G [00:19<00:28, 229MB/s]
#
#
#
# model-00001-of-00002.safetensors:  36%|█▊   | 3.54G/9.98G [00:19<00:26, 240MB/s]
#
#
#
# model-00001-of-00002.safetensors:  36%|█▊   | 3.58G/9.98G [00:19<00:25, 248MB/s]
#
#
#
# model-00001-of-00002.safetensors:  36%|█▊   | 3.61G/9.98G [00:19<00:25, 252MB/s]
#
#
#
# model-00001-of-00002.safetensors:  36%|█▊   | 3.64G/9.98G [00:19<00:24, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  37%|█▊   | 3.67G/9.98G [00:19<00:24, 260MB/s]
#
#
#
# model-00001-of-00002.safetensors:  37%|█▊   | 3.70G/9.98G [00:20<00:23, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  37%|█▊   | 3.73G/9.98G [00:20<00:23, 266MB/s]
#
#
#
# model-00001-of-00002.safetensors:  38%|█▉   | 3.76G/9.98G [00:20<00:23, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  38%|█▉   | 3.80G/9.98G [00:20<00:23, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  38%|█▉   | 3.83G/9.98G [00:20<00:23, 263MB/s]
#
#
#
# model-00001-of-00002.safetensors:  39%|█▉   | 3.86G/9.98G [00:20<00:23, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  39%|█▉   | 3.89G/9.98G [00:20<00:23, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  39%|█▉   | 3.92G/9.98G [00:20<00:22, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  40%|█▉   | 3.95G/9.98G [00:20<00:22, 265MB/s]
#
#
#
# model-00001-of-00002.safetensors:  40%|█▉   | 3.98G/9.98G [00:21<00:22, 267MB/s]
#
#
#
# model-00001-of-00002.safetensors:  40%|██   | 4.02G/9.98G [00:21<00:22, 268MB/s]
#
#
#
# model-00001-of-00002.safetensors:  41%|██   | 4.05G/9.98G [00:21<00:22, 269MB/s]
#
#
#
# model-00001-of-00002.safetensors:  41%|██   | 4.08G/9.98G [00:21<00:21, 270MB/s]
#
#
#
# model-00001-of-00002.safetensors:  41%|██   | 4.11G/9.98G [00:21<00:33, 177MB/s]
#
#
#
# model-00001-of-00002.safetensors:  42%|██   | 4.14G/9.98G [00:21<00:29, 196MB/s]
#
#
#
# model-00001-of-00002.safetensors:  42%|██   | 4.17G/9.98G [00:22<00:26, 215MB/s]
#
#
#
# model-00001-of-00002.safetensors:  42%|██   | 4.20G/9.98G [00:22<00:25, 231MB/s]
#
#
#
# model-00001-of-00002.safetensors:  42%|██   | 4.24G/9.98G [00:22<00:23, 241MB/s]
#
#
#
# model-00001-of-00002.safetensors:  43%|██▏  | 4.27G/9.98G [00:22<00:22, 250MB/s]
#
#
#
# model-00001-of-00002.safetensors:  43%|██▏  | 4.30G/9.98G [00:22<00:22, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  43%|██▏  | 4.33G/9.98G [00:22<00:21, 260MB/s]
#
#
#
# model-00001-of-00002.safetensors:  44%|██▏  | 4.36G/9.98G [00:22<00:21, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  44%|██▏  | 4.39G/9.98G [00:22<00:21, 265MB/s]
#
#
#
# model-00001-of-00002.safetensors:  44%|██▏  | 4.42G/9.98G [00:22<00:20, 266MB/s]
#
#
#
# model-00001-of-00002.safetensors:  45%|██▏  | 4.46G/9.98G [00:23<00:20, 268MB/s]
#
#
#
# model-00001-of-00002.safetensors:  45%|██▏  | 4.49G/9.98G [00:23<00:20, 269MB/s]
#
#
#
# model-00001-of-00002.safetensors:  45%|██▎  | 4.52G/9.98G [00:23<00:20, 269MB/s]
#
#
#
# model-00001-of-00002.safetensors:  46%|██▎  | 4.55G/9.98G [00:23<00:20, 269MB/s]
#
#
#
# model-00001-of-00002.safetensors:  46%|██▎  | 4.58G/9.98G [00:23<00:21, 252MB/s]
#
#
#
# model-00001-of-00002.safetensors:  46%|██▎  | 4.61G/9.98G [00:23<00:25, 210MB/s]
#
#
#
# model-00001-of-00002.safetensors:  47%|██▎  | 4.65G/9.98G [00:24<00:30, 174MB/s]
#
#
#
# model-00001-of-00002.safetensors:  47%|██▎  | 4.67G/9.98G [00:24<00:34, 152MB/s]
#
#
#
# model-00001-of-00002.safetensors:  47%|██▎  | 4.69G/9.98G [00:24<00:36, 145MB/s]
#
#
#
# model-00001-of-00002.safetensors:  47%|██▎  | 4.71G/9.98G [00:24<00:38, 136MB/s]
#
#
#
# model-00001-of-00002.safetensors:  47%|██▎  | 4.73G/9.98G [00:24<00:39, 132MB/s]
#
#
#
# model-00001-of-00002.safetensors:  48%|██▍  | 4.75G/9.98G [00:24<00:38, 135MB/s]
#
#
#
# model-00001-of-00002.safetensors:  48%|██▍  | 4.77G/9.98G [00:25<00:39, 133MB/s]
#
#
#
# model-00001-of-00002.safetensors:  48%|██▍  | 4.79G/9.98G [00:25<00:38, 133MB/s]
#
#
#
# model-00001-of-00002.safetensors:  48%|██▍  | 4.81G/9.98G [00:25<00:37, 139MB/s]
#
#
#
# model-00001-of-00002.safetensors:  48%|██▍  | 4.83G/9.98G [00:25<00:36, 140MB/s]
#
#
#
# model-00001-of-00002.safetensors:  49%|██▍  | 4.85G/9.98G [00:25<00:35, 143MB/s]
#
#
#
# model-00001-of-00002.safetensors:  49%|██▍  | 4.88G/9.98G [00:25<00:36, 138MB/s]
#
#
#
# model-00001-of-00002.safetensors:  49%|██▍  | 4.90G/9.98G [00:26<00:43, 117MB/s]
#
#
#
# model-00001-of-00002.safetensors:  49%|██▍  | 4.92G/9.98G [00:26<00:42, 120MB/s]
#
#
#
# model-00001-of-00002.safetensors:  50%|██▍  | 4.94G/9.98G [00:26<00:39, 128MB/s]
#
#
#
# model-00001-of-00002.safetensors:  50%|██▍  | 4.96G/9.98G [00:26<00:44, 112MB/s]
#
#
#
# model-00001-of-00002.safetensors:  50%|██▍  | 4.98G/9.98G [00:26<00:48, 104MB/s]
#
#
#
# model-00001-of-00002.safetensors:  50%|██▌  | 5.00G/9.98G [00:26<00:46, 108MB/s]
#
#
#
# model-00001-of-00002.safetensors:  50%|██▌  | 5.03G/9.98G [00:27<00:37, 131MB/s]
#
#
#
# model-00001-of-00002.safetensors:  51%|██▌  | 5.05G/9.98G [00:27<00:41, 117MB/s]
#
#
#
# model-00001-of-00002.safetensors:  51%|██▌  | 5.08G/9.98G [00:27<00:45, 108MB/s]
#
#
#
# model-00001-of-00002.safetensors:  51%|██▌  | 5.10G/9.98G [00:27<00:45, 107MB/s]
#
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.12G/9.98G [00:28<00:50, 96.3MB/s]
#
#
#
# model-00001-of-00002.safetensors:  51%|██  | 5.13G/9.98G [00:28<00:51, 93.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.14G/9.98G [00:28<00:52, 91.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.15G/9.98G [00:28<00:52, 91.6MB/s]
#
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.17G/9.98G [00:28<00:49, 97.7MB/s]
#
#
#
# model-00001-of-00002.safetensors:  52%|██  | 5.18G/9.98G [00:28<00:49, 96.3MB/s]
#
#
#
# model-00001-of-00002.safetensors:  52%|██▌  | 5.20G/9.98G [00:28<00:43, 110MB/s]
#
#
#
# model-00001-of-00002.safetensors:  52%|██▌  | 5.22G/9.98G [00:29<00:39, 121MB/s]
#
#
#
# model-00001-of-00002.safetensors:  53%|██▋  | 5.25G/9.98G [00:29<00:30, 154MB/s]
#
#
#
# model-00001-of-00002.safetensors:  53%|██▋  | 5.28G/9.98G [00:29<00:25, 183MB/s]
#
#
#
# model-00001-of-00002.safetensors:  53%|██▋  | 5.32G/9.98G [00:29<00:22, 205MB/s]
#
#
#
# model-00001-of-00002.safetensors:  54%|██▋  | 5.35G/9.98G [00:29<00:20, 221MB/s]
#
#
#
# model-00001-of-00002.safetensors:  54%|██▋  | 5.38G/9.98G [00:29<00:19, 234MB/s]
#
#
#
# model-00001-of-00002.safetensors:  54%|██▋  | 5.41G/9.98G [00:29<00:18, 243MB/s]
#
#
#
# model-00001-of-00002.safetensors:  55%|██▋  | 5.44G/9.98G [00:29<00:18, 250MB/s]
#
#
#
# model-00001-of-00002.safetensors:  55%|██▋  | 5.47G/9.98G [00:29<00:17, 253MB/s]
#
#
#
# model-00001-of-00002.safetensors:  55%|██▊  | 5.51G/9.98G [00:30<00:17, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  55%|██▊  | 5.54G/9.98G [00:30<00:16, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  56%|██▊  | 5.57G/9.98G [00:30<00:16, 263MB/s]
#
#
#
# model-00001-of-00002.safetensors:  56%|██▊  | 5.60G/9.98G [00:30<00:16, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  56%|██▊  | 5.63G/9.98G [00:30<00:17, 251MB/s]
#
#
#
# model-00001-of-00002.safetensors:  57%|██▊  | 5.66G/9.98G [00:30<00:17, 252MB/s]
#
#
#
# model-00001-of-00002.safetensors:  57%|██▊  | 5.69G/9.98G [00:30<00:16, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  57%|██▊  | 5.73G/9.98G [00:30<00:16, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  58%|██▉  | 5.76G/9.98G [00:31<00:16, 256MB/s]
#
#
#
# model-00001-of-00002.safetensors:  58%|██▉  | 5.79G/9.98G [00:31<00:16, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  58%|██▉  | 5.82G/9.98G [00:31<00:16, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  59%|██▉  | 5.85G/9.98G [00:31<00:16, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  59%|██▉  | 5.88G/9.98G [00:31<00:16, 254MB/s]
#
#
#
# model-00001-of-00002.safetensors:  59%|██▉  | 5.91G/9.98G [00:31<00:15, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  60%|██▉  | 5.95G/9.98G [00:31<00:15, 256MB/s]
#
#
#
# model-00001-of-00002.safetensors:  60%|██▉  | 5.98G/9.98G [00:31<00:15, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:  60%|███  | 6.01G/9.98G [00:32<00:15, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  61%|███  | 6.04G/9.98G [00:32<00:15, 256MB/s]
#
#
#
# model-00001-of-00002.safetensors:  61%|███  | 6.07G/9.98G [00:32<00:15, 260MB/s]
#
#
#
# model-00001-of-00002.safetensors:  61%|███  | 6.10G/9.98G [00:32<00:14, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  61%|███  | 6.13G/9.98G [00:32<00:14, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  62%|███  | 6.17G/9.98G [00:32<00:14, 263MB/s]
#
#
#
# model-00001-of-00002.safetensors:  62%|███  | 6.20G/9.98G [00:32<00:14, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  62%|███  | 6.23G/9.98G [00:32<00:14, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  63%|███▏ | 6.26G/9.98G [00:33<00:13, 269MB/s]
#
#
#
# model-00001-of-00002.safetensors:  63%|███▏ | 6.29G/9.98G [00:33<00:13, 267MB/s]
#
#
#
# model-00001-of-00002.safetensors:  63%|███▏ | 6.32G/9.98G [00:33<00:13, 271MB/s]
#
#
#
# model-00001-of-00002.safetensors:  64%|███▏ | 6.35G/9.98G [00:33<00:13, 274MB/s]
#
#
#
# model-00001-of-00002.safetensors:  64%|███▏ | 6.39G/9.98G [00:33<00:13, 276MB/s]
#
#
#
# model-00001-of-00002.safetensors:  64%|███▏ | 6.42G/9.98G [00:33<00:12, 274MB/s]
#
#
#
# model-00001-of-00002.safetensors:  65%|███▏ | 6.45G/9.98G [00:33<00:12, 275MB/s]
#
#
#
# model-00001-of-00002.safetensors:  65%|███▏ | 6.48G/9.98G [00:33<00:12, 274MB/s]
#
#
#
# model-00001-of-00002.safetensors:  65%|███▎ | 6.51G/9.98G [00:33<00:12, 273MB/s]
#
#
#
# model-00001-of-00002.safetensors:  66%|███▎ | 6.54G/9.98G [00:34<00:12, 273MB/s]
#
#
#
# model-00001-of-00002.safetensors:  66%|███▎ | 6.57G/9.98G [00:34<00:12, 273MB/s]
#
#
#
# model-00001-of-00002.safetensors:  66%|███▎ | 6.61G/9.98G [00:34<00:12, 273MB/s]
#
#
#
# model-00001-of-00002.safetensors:  67%|███▎ | 6.64G/9.98G [00:34<00:12, 274MB/s]
#
#
#
# model-00001-of-00002.safetensors:  67%|███▎ | 6.67G/9.98G [00:34<00:12, 273MB/s]
#
#
#
# model-00001-of-00002.safetensors:  67%|███▎ | 6.70G/9.98G [00:34<00:12, 271MB/s]
#
#
#
# model-00001-of-00002.safetensors:  67%|███▎ | 6.73G/9.98G [00:34<00:11, 271MB/s]
#
#
#
# model-00001-of-00002.safetensors:  68%|███▍ | 6.76G/9.98G [00:34<00:11, 271MB/s]
#
#
#
# model-00001-of-00002.safetensors:  68%|███▍ | 6.79G/9.98G [00:34<00:11, 271MB/s]
#
#
#
# model-00001-of-00002.safetensors:  68%|███▍ | 6.83G/9.98G [00:35<00:11, 266MB/s]
#
#
#
# model-00001-of-00002.safetensors:  69%|███▍ | 6.86G/9.98G [00:35<00:11, 267MB/s]
#
#
#
# model-00001-of-00002.safetensors:  69%|███▍ | 6.89G/9.98G [00:35<00:11, 268MB/s]
#
#
#
# model-00001-of-00002.safetensors:  69%|███▍ | 6.92G/9.98G [00:35<00:11, 268MB/s]
#
#
#
# model-00001-of-00002.safetensors:  70%|███▍ | 6.95G/9.98G [00:35<00:11, 268MB/s]
#
#
#
# model-00001-of-00002.safetensors:  70%|███▍ | 6.98G/9.98G [00:35<00:11, 269MB/s]
#
#
#
# model-00001-of-00002.safetensors:  70%|███▌ | 7.01G/9.98G [00:35<00:11, 269MB/s]
#
#
#
# model-00001-of-00002.safetensors:  71%|███▌ | 7.05G/9.98G [00:35<00:10, 268MB/s]
#
#
#
# model-00001-of-00002.safetensors:  71%|███▌ | 7.08G/9.98G [00:36<00:10, 269MB/s]
#
#
#
# model-00001-of-00002.safetensors:  71%|███▌ | 7.11G/9.98G [00:36<00:10, 270MB/s]
#
#
#
# model-00001-of-00002.safetensors:  72%|███▌ | 7.14G/9.98G [00:36<00:10, 271MB/s]
#
#
#
# model-00001-of-00002.safetensors:  72%|███▌ | 7.17G/9.98G [00:36<00:10, 273MB/s]
#
#
#
# model-00001-of-00002.safetensors:  72%|███▌ | 7.20G/9.98G [00:36<00:10, 275MB/s]
#
#
#
# model-00001-of-00002.safetensors:  73%|███▋ | 7.24G/9.98G [00:36<00:09, 277MB/s]
#
#
#
# model-00001-of-00002.safetensors:  73%|███▋ | 7.27G/9.98G [00:36<00:09, 277MB/s]
#
#
#
# model-00001-of-00002.safetensors:  73%|███▋ | 7.30G/9.98G [00:37<00:14, 180MB/s]
#
#
#
# model-00001-of-00002.safetensors:  73%|███▋ | 7.33G/9.98G [00:37<00:13, 201MB/s]
#
#
#
# model-00001-of-00002.safetensors:  74%|███▋ | 7.36G/9.98G [00:37<00:11, 220MB/s]
#
#
#
# model-00001-of-00002.safetensors:  74%|███▋ | 7.39G/9.98G [00:37<00:10, 235MB/s]
#
#
#
# model-00001-of-00002.safetensors:  74%|███▋ | 7.42G/9.98G [00:37<00:10, 247MB/s]
#
#
#
# model-00001-of-00002.safetensors:  75%|███▋ | 7.46G/9.98G [00:37<00:09, 256MB/s]
#
#
#
# model-00001-of-00002.safetensors:  75%|███▊ | 7.49G/9.98G [00:37<00:09, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  75%|███▊ | 7.52G/9.98G [00:37<00:09, 267MB/s]
#
#
#
# model-00001-of-00002.safetensors:  76%|███▊ | 7.55G/9.98G [00:37<00:09, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  76%|███▊ | 7.58G/9.98G [00:38<00:13, 182MB/s]
#
#
#
# model-00001-of-00002.safetensors:  76%|███▊ | 7.61G/9.98G [00:38<00:14, 160MB/s]
#
#
#
# model-00001-of-00002.safetensors:  77%|███▊ | 7.63G/9.98G [00:38<00:15, 147MB/s]
#
#
#
# model-00001-of-00002.safetensors:  77%|███▊ | 7.65G/9.98G [00:38<00:16, 143MB/s]
#
#
#
# model-00001-of-00002.safetensors:  77%|███▊ | 7.68G/9.98G [00:38<00:16, 143MB/s]
#
#
#
# model-00001-of-00002.safetensors:  77%|███▊ | 7.70G/9.98G [00:39<00:16, 138MB/s]
#
#
#
# model-00001-of-00002.safetensors:  77%|███▊ | 7.72G/9.98G [00:39<00:16, 141MB/s]
#
#
#
# model-00001-of-00002.safetensors:  78%|███▉ | 7.74G/9.98G [00:39<00:16, 139MB/s]
#
#
#
# model-00001-of-00002.safetensors:  78%|███▉ | 7.76G/9.98G [00:39<00:16, 132MB/s]
#
#
#
# model-00001-of-00002.safetensors:  78%|███▉ | 7.78G/9.98G [00:39<00:17, 127MB/s]
#
#
#
# model-00001-of-00002.safetensors:  78%|███▉ | 7.80G/9.98G [00:40<00:19, 114MB/s]
#
#
#
# model-00001-of-00002.safetensors:  78%|███▉ | 7.82G/9.98G [00:40<00:19, 110MB/s]
#
#
#
# model-00001-of-00002.safetensors:  79%|███▉ | 7.84G/9.98G [00:40<00:17, 123MB/s]
#
#
#
# model-00001-of-00002.safetensors:  79%|███▉ | 7.86G/9.98G [00:40<00:16, 127MB/s]
#
#
#
# model-00001-of-00002.safetensors:  79%|███▉ | 7.89G/9.98G [00:40<00:19, 108MB/s]
#
#
#
# model-00001-of-00002.safetensors:  79%|███▉ | 7.91G/9.98G [00:41<00:20, 101MB/s]
#
#
#
# model-00001-of-00002.safetensors:  79%|███▏| 7.93G/9.98G [00:41<00:22, 92.7MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 7.94G/9.98G [00:41<00:21, 93.0MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 7.95G/9.98G [00:41<00:23, 85.8MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 7.96G/9.98G [00:41<00:23, 87.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 7.97G/9.98G [00:41<00:23, 84.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 7.98G/9.98G [00:41<00:22, 87.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 7.99G/9.98G [00:42<00:21, 91.2MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 8.00G/9.98G [00:42<00:21, 91.8MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 8.01G/9.98G [00:42<00:22, 86.2MB/s]
#
#
#
# model-00001-of-00002.safetensors:  80%|███▏| 8.02G/9.98G [00:42<00:22, 87.0MB/s]
#
#
#
# model-00001-of-00002.safetensors:  81%|███▏| 8.03G/9.98G [00:42<00:21, 88.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:  81%|███▏| 8.04G/9.98G [00:42<00:21, 88.1MB/s]
#
#
#
# model-00001-of-00002.safetensors:  81%|███▏| 8.05G/9.98G [00:42<00:21, 90.2MB/s]
#
#
#
# model-00001-of-00002.safetensors:  81%|███▏| 8.07G/9.98G [00:42<00:19, 95.3MB/s]
#
#
#
# model-00001-of-00002.safetensors:  81%|███▏| 8.08G/9.98G [00:43<00:20, 90.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  81%|███▏| 8.10G/9.98G [00:43<00:21, 88.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:  81%|███▎| 8.12G/9.98G [00:43<00:20, 88.9MB/s]
#
#
#
# model-00001-of-00002.safetensors:  81%|███▎| 8.13G/9.98G [00:43<00:20, 89.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:  82%|███▎| 8.14G/9.98G [00:43<00:20, 88.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:  82%|███▎| 8.16G/9.98G [00:43<00:18, 97.0MB/s]
#
#
#
# model-00001-of-00002.safetensors:  82%|███▎| 8.17G/9.98G [00:43<00:18, 95.3MB/s]
#
#
#
# model-00001-of-00002.safetensors:  82%|███▎| 8.18G/9.98G [00:44<00:19, 93.7MB/s]
#
#
#
# model-00001-of-00002.safetensors:  82%|████ | 8.21G/9.98G [00:44<00:12, 139MB/s]
#
#
#
# model-00001-of-00002.safetensors:  83%|████▏| 8.24G/9.98G [00:44<00:09, 174MB/s]
#
#
#
# model-00001-of-00002.safetensors:  83%|████▏| 8.27G/9.98G [00:44<00:08, 199MB/s]
#
#
#
# model-00001-of-00002.safetensors:  83%|████▏| 8.30G/9.98G [00:44<00:07, 216MB/s]
#
#
#
# model-00001-of-00002.safetensors:  84%|████▏| 8.34G/9.98G [00:44<00:07, 229MB/s]
#
#
#
# model-00001-of-00002.safetensors:  84%|████▏| 8.37G/9.98G [00:44<00:06, 240MB/s]
#
#
#
# model-00001-of-00002.safetensors:  84%|████▏| 8.40G/9.98G [00:44<00:06, 246MB/s]
#
#
#
# model-00001-of-00002.safetensors:  85%|████▏| 8.43G/9.98G [00:45<00:06, 251MB/s]
#
#
#
# model-00001-of-00002.safetensors:  85%|████▏| 8.46G/9.98G [00:45<00:06, 251MB/s]
#
#
#
# model-00001-of-00002.safetensors:  85%|████▎| 8.49G/9.98G [00:45<00:05, 254MB/s]
#
#
#
# model-00001-of-00002.safetensors:  85%|████▎| 8.52G/9.98G [00:45<00:05, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  86%|████▎| 8.56G/9.98G [00:45<00:05, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  86%|████▎| 8.59G/9.98G [00:45<00:05, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  86%|████▎| 8.62G/9.98G [00:45<00:05, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  87%|████▎| 8.65G/9.98G [00:45<00:05, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:  87%|████▎| 8.68G/9.98G [00:46<00:05, 258MB/s]
#
#
#
# model-00001-of-00002.safetensors:  87%|████▎| 8.71G/9.98G [00:46<00:04, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  88%|████▍| 8.75G/9.98G [00:46<00:04, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  88%|████▍| 8.78G/9.98G [00:46<00:04, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  88%|████▍| 8.81G/9.98G [00:46<00:04, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  89%|████▍| 8.84G/9.98G [00:46<00:04, 261MB/s]
#
#
#
# model-00001-of-00002.safetensors:  89%|████▍| 8.87G/9.98G [00:46<00:04, 263MB/s]
#
#
#
# model-00001-of-00002.safetensors:  89%|████▍| 8.90G/9.98G [00:46<00:04, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  90%|████▍| 8.93G/9.98G [00:46<00:03, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  90%|████▍| 8.97G/9.98G [00:47<00:03, 262MB/s]
#
#
#
# model-00001-of-00002.safetensors:  90%|████▌| 9.00G/9.98G [00:47<00:03, 260MB/s]
#
#
#
# model-00001-of-00002.safetensors:  90%|████▌| 9.03G/9.98G [00:47<00:03, 258MB/s]
#
#
#
# model-00001-of-00002.safetensors:  91%|████▌| 9.06G/9.98G [00:47<00:03, 257MB/s]
#
#
#
# model-00001-of-00002.safetensors:  91%|███▋| 9.09G/9.98G [00:49<00:15, 58.1MB/s]
#
#
#
# model-00001-of-00002.safetensors:  91%|███▋| 9.11G/9.98G [00:49<00:12, 67.3MB/s]
#
#
#
# model-00001-of-00002.safetensors:  92%|███▋| 9.13G/9.98G [00:50<00:23, 36.2MB/s]
#
#
#
# model-00001-of-00002.safetensors:  92%|███▋| 9.15G/9.98G [00:50<00:18, 44.9MB/s]
#
#
#
# model-00001-of-00002.safetensors:  92%|███▋| 9.19G/9.98G [00:50<00:12, 62.7MB/s]
#
#
#
# model-00001-of-00002.safetensors:  92%|███▋| 9.21G/9.98G [00:52<00:23, 32.8MB/s]
#
#
#
# model-00001-of-00002.safetensors:  92%|███▋| 9.23G/9.98G [00:52<00:18, 41.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  93%|███▋| 9.25G/9.98G [00:53<00:25, 28.6MB/s]
#
#
#
# model-00001-of-00002.safetensors:  93%|███▋| 9.27G/9.98G [00:53<00:19, 37.0MB/s]
#
#
#
# model-00001-of-00002.safetensors:  93%|███▋| 9.30G/9.98G [00:55<00:23, 29.1MB/s]
#
#
#
# model-00001-of-00002.safetensors:  93%|███▋| 9.32G/9.98G [00:55<00:17, 36.9MB/s]
#
#
#
# model-00001-of-00002.safetensors:  94%|███▋| 9.34G/9.98G [00:55<00:13, 46.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  94%|███▊| 9.37G/9.98G [00:55<00:09, 66.2MB/s]
#
#
#
# model-00001-of-00002.safetensors:  94%|███▊| 9.40G/9.98G [00:56<00:08, 69.7MB/s]
#
#
#
# model-00001-of-00002.safetensors:  94%|███▊| 9.42G/9.98G [00:56<00:06, 83.7MB/s]
#
#
#
# model-00001-of-00002.safetensors:  95%|████▋| 9.45G/9.98G [00:56<00:04, 112MB/s]
#
#
#
# model-00001-of-00002.safetensors:  95%|████▊| 9.48G/9.98G [00:56<00:03, 141MB/s]
#
#
#
# model-00001-of-00002.safetensors:  95%|████▊| 9.51G/9.98G [00:56<00:02, 168MB/s]
#
#
#
# model-00001-of-00002.safetensors:  96%|████▊| 9.54G/9.98G [00:56<00:02, 192MB/s]
#
#
#
# model-00001-of-00002.safetensors:  96%|████▊| 9.57G/9.98G [00:56<00:01, 212MB/s]
#
#
#
# model-00001-of-00002.safetensors:  96%|████▊| 9.60G/9.98G [00:56<00:01, 227MB/s]
#
#
#
# model-00001-of-00002.safetensors:  97%|████▊| 9.64G/9.98G [00:57<00:01, 239MB/s]
#
#
#
# model-00001-of-00002.safetensors:  97%|████▊| 9.67G/9.98G [00:57<00:01, 248MB/s]
#
#
#
# model-00001-of-00002.safetensors:  97%|████▊| 9.70G/9.98G [00:57<00:01, 255MB/s]
#
#
#
# model-00001-of-00002.safetensors:  98%|████▉| 9.73G/9.98G [00:57<00:00, 259MB/s]
#
#
#
# model-00001-of-00002.safetensors:  98%|████▉| 9.76G/9.98G [00:57<00:00, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  98%|████▉| 9.79G/9.98G [00:57<00:00, 265MB/s]
#
#
#
# model-00001-of-00002.safetensors:  98%|████▉| 9.83G/9.98G [00:57<00:00, 268MB/s]
#
#
#
# model-00001-of-00002.safetensors:  99%|████▉| 9.86G/9.98G [00:57<00:00, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors:  99%|████▉| 9.89G/9.98G [00:57<00:00, 263MB/s]
#
#
#
# model-00001-of-00002.safetensors:  99%|████▉| 9.92G/9.98G [00:58<00:00, 264MB/s]
#
#
#
# model-00001-of-00002.safetensors: 100%|█████| 9.98G/9.98G [00:58<00:00, 171MB/s]
#
# Fetching 10 files: 100%|████████████████████████| 10/10 [00:58<00:00,  5.87s/it]
# Warmup loader cache:  50%|████████████            | 1/2 [00:58<00:58, 58.90s/it]
# Fetching 11 files:   0%|                                 | 0/11 [00:00<?, ?it/s]
#
# model-00004-of-00004.safetensors:   0%|             | 0.00/1.17G [00:00<?, ?B/s]
#
#
# model.safetensors.index.json: 100%|████████| 23.9k/23.9k [00:00<00:00, 58.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:   0%|             | 0.00/4.92G [00:00<?, ?B/s]
#
#
#
# original/params.json: 100%|████████████████████| 211/211 [00:00<00:00, 1.09MB/s]
#
#
#
#
# special_tokens_map.json: 100%|████████████████| 73.0/73.0 [00:00<00:00, 411kB/s]
#
#
#
#
# model-00001-of-00004.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
# model-00002-of-00004.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   1%|     | 10.5M/1.17G [00:00<00:11, 105MB/s]
#
#
# model-00003-of-00004.safetensors:   0%|    | 10.5M/4.92G [00:00<00:53, 92.2MB/s]
#
#
#
#
#
# tokenizer_config.json: 100%|███████████████| 51.0k/51.0k [00:00<00:00, 13.1MB/s]
#
#
#
#
#
#
# generation_config.json: 100%|███████████████████| 187/187 [00:00<00:00, 887kB/s]
#
# Fetching 11 files:  18%|████▌                    | 2/11 [00:00<00:01,  4.90it/s]
#
#
# model-00003-of-00004.safetensors:   1%|     | 31.5M/4.92G [00:00<00:34, 142MB/s]
#
#
#
#
#
# tokenizer.json:   0%|                               | 0.00/9.09M [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   3%|▏    | 31.5M/1.17G [00:00<00:09, 124MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0%|    | 10.5M/4.98G [00:00<02:06, 39.1MB/s]
#
#
# model-00003-of-00004.safetensors:   1%|     | 52.4M/4.92G [00:00<00:31, 156MB/s]
#
# model-00004-of-00004.safetensors:   4%|▏    | 52.4M/1.17G [00:00<00:07, 144MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   0%|    | 10.5M/5.00G [00:00<02:41, 30.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:   0%|    | 21.0M/4.98G [00:00<01:22, 60.3MB/s]
#
#
# model-00003-of-00004.safetensors:   1%|     | 73.4M/4.92G [00:00<00:32, 148MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   0%|    | 21.0M/5.00G [00:00<01:38, 50.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:   1%|    | 31.5M/4.98G [00:00<01:07, 73.6MB/s]
#
# model-00004-of-00004.safetensors:   6%|▎    | 73.4M/1.17G [00:00<00:08, 132MB/s]
#
#
# model-00003-of-00004.safetensors:   2%|     | 94.4M/4.92G [00:00<00:32, 146MB/s]
#
#
#
#
#
# tokenizer.json: 100%|██████████████████████| 9.09M/9.09M [00:00<00:00, 20.2MB/s]
#
#
#
#
# tokenizer.json: 100%|██████████████████████| 9.09M/9.09M [00:00<00:00, 19.7MB/s]
#
#
# model-00004-of-00004.safetensors:   8%|▍    | 94.4M/1.17G [00:00<00:08, 129MB/s]
#
#
#
# model-00001-of-00004.safetensors:   1%|    | 52.4M/4.98G [00:00<00:53, 91.7MB/s]
#
#
# model-00003-of-00004.safetensors:   2%|▏     | 115M/4.92G [00:00<00:35, 134MB/s]
#
#
#
# model-00001-of-00004.safetensors:   1%|     | 73.4M/4.98G [00:00<00:42, 116MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   1%|    | 62.9M/5.00G [00:00<00:50, 98.7MB/s]
#
# model-00004-of-00004.safetensors:  10%|▌     | 115M/1.17G [00:00<00:08, 127MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   2%|     | 83.9M/5.00G [00:00<00:42, 116MB/s]
#
#
#
# model-00001-of-00004.safetensors:   2%|     | 94.4M/4.98G [00:00<00:40, 121MB/s]
#
#
# model-00003-of-00004.safetensors:   3%|▏     | 136M/4.92G [00:01<00:37, 126MB/s]
#
# model-00004-of-00004.safetensors:  12%|▋     | 136M/1.17G [00:01<00:07, 133MB/s]
#
#
#
# model-00001-of-00004.safetensors:   2%|▏     | 115M/4.98G [00:01<00:37, 131MB/s]
#
#
# model-00003-of-00004.safetensors:   3%|▏     | 157M/4.92G [00:01<00:35, 135MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   2%|▏     | 105M/5.00G [00:01<00:41, 119MB/s]
#
# model-00004-of-00004.safetensors:  13%|▊     | 157M/1.17G [00:01<00:07, 134MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   3%|▏     | 126M/5.00G [00:01<00:37, 131MB/s]
#
#
# model-00003-of-00004.safetensors:   4%|▏     | 178M/4.92G [00:01<00:34, 139MB/s]
#
#
#
# model-00001-of-00004.safetensors:   3%|▏     | 136M/4.98G [00:01<00:36, 133MB/s]
#
# model-00004-of-00004.safetensors:  15%|▉     | 178M/1.17G [00:01<00:07, 135MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   3%|▏     | 147M/5.00G [00:01<00:35, 138MB/s]
#
#
# model-00003-of-00004.safetensors:   4%|▏     | 199M/4.92G [00:01<00:35, 134MB/s]
#
#
#
# model-00001-of-00004.safetensors:   3%|▏     | 157M/4.98G [00:01<00:37, 129MB/s]
#
# model-00004-of-00004.safetensors:  17%|█     | 199M/1.17G [00:01<00:07, 132MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   3%|▏     | 168M/5.00G [00:01<00:35, 135MB/s]
#
#
# model-00003-of-00004.safetensors:   4%|▎     | 220M/4.92G [00:01<00:34, 135MB/s]
#
#
#
# model-00001-of-00004.safetensors:   4%|▏     | 178M/4.98G [00:01<00:38, 126MB/s]
#
# model-00004-of-00004.safetensors:  19%|█▏    | 220M/1.17G [00:01<00:07, 129MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:   4%|▏     | 189M/5.00G [00:01<00:34, 139MB/s]
#
#
# model-00003-of-00004.safetensors:   5%|▎     | 241M/4.92G [00:01<00:35, 132MB/s]
#
#
#
# ...
#
#
#
#
# model-00002-of-00004.safetensors:  79%|███▉ | 3.96G/5.00G [00:45<00:08, 122MB/s]
#
#
# model-00003-of-00004.safetensors:  81%|████ | 4.01G/4.92G [00:45<00:06, 130MB/s]
#
#
#
# model-00001-of-00004.safetensors:  80%|███▉ | 3.97G/4.98G [00:45<00:08, 123MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  80%|███▉ | 3.98G/5.00G [00:45<00:08, 126MB/s]
#
#
# model-00003-of-00004.safetensors:  82%|████ | 4.03G/4.92G [00:45<00:06, 127MB/s]
#
#
#
# model-00001-of-00004.safetensors:  80%|████ | 4.00G/4.98G [00:45<00:07, 125MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  80%|████ | 4.01G/5.00G [00:45<00:07, 125MB/s]
#
#
# model-00003-of-00004.safetensors:  82%|████ | 4.05G/4.92G [00:45<00:06, 132MB/s]
#
#
#
# model-00001-of-00004.safetensors:  81%|████ | 4.02G/4.98G [00:45<00:07, 125MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  81%|████ | 4.03G/5.00G [00:45<00:07, 123MB/s]
#
#
# model-00003-of-00004.safetensors:  83%|████▏| 4.07G/4.92G [00:46<00:06, 129MB/s]
#
#
#
# model-00001-of-00004.safetensors:  81%|████ | 4.04G/4.98G [00:46<00:07, 124MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  81%|████ | 4.05G/5.00G [00:46<00:07, 123MB/s]
#
#
# model-00003-of-00004.safetensors:  83%|████▏| 4.09G/4.92G [00:46<00:06, 126MB/s]
#
#
#
# model-00001-of-00004.safetensors:  82%|████ | 4.06G/4.98G [00:46<00:07, 124MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  81%|████ | 4.07G/5.00G [00:46<00:07, 127MB/s]
#
#
# model-00003-of-00004.safetensors:  84%|████▏| 4.11G/4.92G [00:46<00:06, 124MB/s]
#
#
#
# model-00001-of-00004.safetensors:  82%|████ | 4.08G/4.98G [00:46<00:07, 124MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  82%|████ | 4.09G/5.00G [00:46<00:07, 126MB/s]
#
#
# model-00003-of-00004.safetensors:  84%|████▏| 4.13G/4.92G [00:46<00:06, 129MB/s]
#
#
#
# model-00001-of-00004.safetensors:  82%|████ | 4.10G/4.98G [00:46<00:06, 128MB/s]
#
#
# model-00003-of-00004.safetensors:  84%|████▏| 4.15G/4.92G [00:46<00:05, 128MB/s]
#
#
#
# model-00001-of-00004.safetensors:  83%|████▏| 4.12G/4.98G [00:46<00:06, 126MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  82%|████ | 4.11G/5.00G [00:46<00:08, 100MB/s]
#
#
# model-00003-of-00004.safetensors:  85%|████▏| 4.17G/4.92G [00:46<00:05, 124MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  83%|████▏| 4.14G/5.00G [00:46<00:06, 130MB/s]
#
#
#
# model-00001-of-00004.safetensors:  83%|████▏| 4.14G/4.98G [00:46<00:06, 123MB/s]
#
#
# model-00003-of-00004.safetensors:  85%|████▎| 4.19G/4.92G [00:47<00:05, 122MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  83%|████▏| 4.16G/5.00G [00:46<00:06, 129MB/s]
#
#
#
# model-00001-of-00004.safetensors:  84%|████▏| 4.16G/4.98G [00:47<00:06, 119MB/s]
#
#
# model-00003-of-00004.safetensors:  86%|████▎| 4.22G/4.92G [00:47<00:05, 122MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  84%|████▏| 4.18G/5.00G [00:47<00:06, 122MB/s]
#
#
#
# model-00001-of-00004.safetensors:  84%|████▏| 4.18G/4.98G [00:47<00:06, 120MB/s]
#
#
# model-00003-of-00004.safetensors:  86%|████▎| 4.24G/4.92G [00:47<00:05, 116MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  84%|████▏| 4.20G/5.00G [00:47<00:06, 116MB/s]
#
#
#
# model-00001-of-00004.safetensors:  84%|████▏| 4.20G/4.98G [00:47<00:06, 114MB/s]
#
#
# model-00003-of-00004.safetensors:  87%|████▎| 4.26G/4.92G [00:47<00:05, 110MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  85%|████▏| 4.23G/5.00G [00:47<00:07, 109MB/s]
#
#
#
# model-00001-of-00004.safetensors:  85%|████▏| 4.23G/4.98G [00:47<00:06, 108MB/s]
#
#
# model-00003-of-00004.safetensors:  87%|████▎| 4.28G/4.92G [00:47<00:06, 104MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  85%|████▏| 4.25G/5.00G [00:47<00:06, 109MB/s]
#
#
#
# model-00001-of-00004.safetensors:  85%|████▎| 4.25G/4.98G [00:47<00:07, 102MB/s]
#
#
# model-00003-of-00004.safetensors:  87%|████▎| 4.30G/4.92G [00:48<00:05, 104MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  85%|████▎| 4.27G/5.00G [00:48<00:07, 100MB/s]
#
#
#
# model-00001-of-00004.safetensors:  86%|████▎| 4.27G/4.98G [00:48<00:07, 101MB/s]
#
#
# model-00003-of-00004.safetensors:  88%|███▌| 4.31G/4.92G [00:48<00:06, 99.5MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  86%|███▍| 4.28G/5.00G [00:48<00:07, 96.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  86%|███▍| 4.28G/4.98G [00:48<00:07, 96.9MB/s]
#
#
# model-00003-of-00004.safetensors:  88%|███▌| 4.32G/4.92G [00:48<00:06, 95.0MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  86%|███▍| 4.29G/5.00G [00:48<00:07, 91.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:  86%|███▍| 4.29G/4.98G [00:48<00:07, 91.4MB/s]
#
#
# model-00003-of-00004.safetensors:  88%|███▌| 4.33G/4.92G [00:48<00:06, 89.9MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  86%|███▍| 4.30G/5.00G [00:48<00:08, 87.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  86%|███▍| 4.30G/4.98G [00:48<00:07, 86.7MB/s]
#
#
# model-00003-of-00004.safetensors:  88%|███▌| 4.34G/4.92G [00:48<00:06, 84.1MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  86%|███▍| 4.31G/5.00G [00:48<00:08, 81.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:  87%|███▍| 4.31G/4.98G [00:48<00:08, 80.8MB/s]
#
#
# model-00003-of-00004.safetensors:  89%|███▌| 4.35G/4.92G [00:48<00:07, 77.9MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  86%|███▍| 4.32G/5.00G [00:48<00:08, 83.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:  87%|███▍| 4.32G/4.98G [00:48<00:08, 74.5MB/s]
#
#
# model-00003-of-00004.safetensors:  89%|███▌| 4.36G/4.92G [00:48<00:07, 72.0MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  87%|███▍| 4.33G/5.00G [00:48<00:08, 74.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:  87%|███▍| 4.33G/4.98G [00:49<00:09, 67.1MB/s]
#
#
# model-00003-of-00004.safetensors:  89%|███▌| 4.37G/4.92G [00:49<00:08, 65.6MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  87%|███▍| 4.34G/5.00G [00:49<00:09, 66.5MB/s]
#
#
# model-00003-of-00004.safetensors:  89%|███▌| 4.38G/4.92G [00:49<00:08, 65.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:  87%|███▍| 4.34G/4.98G [00:49<00:10, 60.4MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  87%|███▍| 4.35G/5.00G [00:49<00:11, 57.4MB/s]
#
#
#
# model-00001-of-00004.safetensors:  87%|███▍| 4.35G/4.98G [00:49<00:10, 60.0MB/s]
#
#
# model-00003-of-00004.safetensors:  89%|███▌| 4.39G/4.92G [00:49<00:09, 56.3MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  87%|███▍| 4.36G/5.00G [00:49<00:13, 48.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:  88%|███▌| 4.36G/4.98G [00:49<00:12, 49.0MB/s]
#
#
# model-00003-of-00004.safetensors:  90%|███▌| 4.40G/4.92G [00:49<00:12, 42.6MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  87%|███▍| 4.37G/5.00G [00:49<00:14, 42.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:  88%|███▌| 4.37G/4.98G [00:50<00:15, 39.8MB/s]
#
#
# model-00003-of-00004.safetensors:  90%|███▌| 4.41G/4.92G [00:50<00:12, 40.6MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  88%|███▌| 4.38G/5.00G [00:50<00:16, 38.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:  88%|███▌| 4.38G/4.98G [00:50<00:15, 39.1MB/s]
#
#
# model-00003-of-00004.safetensors:  90%|███▌| 4.42G/4.92G [00:50<00:12, 40.1MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  88%|███▌| 4.39G/5.00G [00:50<00:15, 38.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:  88%|███▌| 4.39G/4.98G [00:50<00:14, 39.5MB/s]
#
#
# model-00003-of-00004.safetensors:  90%|███▌| 4.44G/4.92G [00:50<00:12, 37.4MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  88%|███▌| 4.40G/5.00G [00:50<00:15, 39.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:  88%|███▌| 4.40G/4.98G [00:50<00:15, 37.3MB/s]
#
#
# model-00003-of-00004.safetensors:  90%|███▌| 4.45G/4.92G [00:51<00:12, 38.4MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  88%|███▌| 4.41G/5.00G [00:51<00:15, 37.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  89%|███▌| 4.41G/4.98G [00:51<00:14, 38.6MB/s]
#
#
# model-00003-of-00004.safetensors:  91%|███▋| 4.46G/4.92G [00:51<00:12, 37.3MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  89%|███▌| 4.42G/5.00G [00:51<00:14, 39.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:  89%|███▌| 4.42G/4.98G [00:51<00:14, 37.9MB/s]
#
#
# model-00003-of-00004.safetensors:  91%|███▋| 4.47G/4.92G [00:51<00:11, 39.2MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  89%|███▌| 4.44G/5.00G [00:51<00:14, 38.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  89%|███▌| 4.44G/4.98G [00:51<00:13, 40.2MB/s]
#
#
# model-00003-of-00004.safetensors:  91%|███▋| 4.48G/4.92G [00:51<00:10, 41.3MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  89%|███▌| 4.45G/5.00G [00:51<00:13, 41.1MB/s]
#
#
#
# model-00001-of-00004.safetensors:  89%|███▌| 4.45G/4.98G [00:51<00:12, 42.3MB/s]
#
#
# model-00003-of-00004.safetensors:  91%|███▋| 4.49G/4.92G [00:52<00:10, 40.8MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  89%|███▌| 4.46G/5.00G [00:52<00:12, 43.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  90%|███▌| 4.46G/4.98G [00:52<00:12, 42.0MB/s]
#
#
# model-00003-of-00004.safetensors:  92%|███▋| 4.50G/4.92G [00:52<00:09, 43.6MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  89%|███▌| 4.47G/5.00G [00:52<00:12, 43.0MB/s]
#
#
#
# model-00001-of-00004.safetensors:  90%|███▌| 4.47G/4.98G [00:52<00:11, 44.9MB/s]
#
#
# model-00003-of-00004.safetensors:  92%|███▋| 4.51G/4.92G [00:52<00:09, 43.5MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  90%|███▌| 4.48G/5.00G [00:52<00:11, 45.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:  90%|███▌| 4.48G/4.98G [00:52<00:11, 44.8MB/s]
#
#
# model-00003-of-00004.safetensors:  92%|███▋| 4.52G/4.92G [00:52<00:08, 46.4MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  90%|███▌| 4.49G/5.00G [00:52<00:11, 45.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:  90%|███▌| 4.49G/4.98G [00:52<00:10, 48.0MB/s]
#
#
# model-00003-of-00004.safetensors:  92%|███▋| 4.53G/4.92G [00:52<00:07, 49.3MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  90%|███▌| 4.50G/5.00G [00:52<00:10, 48.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:  90%|███▌| 4.50G/4.98G [00:53<00:09, 50.5MB/s]
#
#
# model-00003-of-00004.safetensors:  92%|███▋| 4.54G/4.92G [00:53<00:07, 48.2MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  90%|███▌| 4.51G/5.00G [00:53<00:09, 50.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  91%|███▌| 4.51G/4.98G [00:53<00:09, 48.2MB/s]
#
#
# model-00003-of-00004.safetensors:  93%|███▋| 4.55G/4.92G [00:53<00:07, 49.7MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  90%|███▌| 4.52G/5.00G [00:53<00:10, 47.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:  91%|███▋| 4.52G/4.98G [00:53<00:09, 49.1MB/s]
#
#
# model-00003-of-00004.safetensors:  93%|███▋| 4.56G/4.92G [00:53<00:07, 46.7MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  91%|███▌| 4.53G/5.00G [00:53<00:09, 48.1MB/s]
#
#
#
# model-00001-of-00004.safetensors:  91%|███▋| 4.53G/4.98G [00:53<00:09, 46.1MB/s]
#
#
# model-00003-of-00004.safetensors:  93%|███▋| 4.57G/4.92G [00:53<00:07, 47.7MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  91%|███▋| 4.54G/5.00G [00:53<00:10, 45.9MB/s]
#
#
# model-00003-of-00004.safetensors:  93%|███▋| 4.58G/4.92G [00:54<00:06, 49.0MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  91%|███▋| 4.55G/5.00G [00:54<00:09, 48.4MB/s]
#
#
#
# model-00001-of-00004.safetensors:  91%|███▋| 4.54G/4.98G [00:54<00:11, 37.3MB/s]
#
#
# model-00003-of-00004.safetensors:  93%|███▋| 4.59G/4.92G [00:54<00:06, 49.3MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  91%|███▋| 4.56G/5.00G [00:54<00:08, 54.3MB/s]
#
#
# model-00003-of-00004.safetensors:  94%|███▋| 4.60G/4.92G [00:54<00:05, 55.9MB/s]
#
#
#
# model-00001-of-00004.safetensors:  92%|███▋| 4.57G/4.98G [00:54<00:06, 64.7MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  91%|███▋| 4.57G/5.00G [00:54<00:07, 58.8MB/s]
#
#
# model-00003-of-00004.safetensors:  94%|███▊| 4.61G/4.92G [00:54<00:04, 61.4MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  92%|███▋| 4.58G/5.00G [00:54<00:06, 67.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:  92%|███▋| 4.58G/4.98G [00:54<00:05, 67.4MB/s]
#
#
# model-00003-of-00004.safetensors:  94%|███▊| 4.63G/4.92G [00:54<00:03, 77.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:  92%|███▋| 4.60G/4.98G [00:54<00:04, 80.2MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  92%|███▋| 4.60G/5.00G [00:54<00:04, 79.6MB/s]
#
#
# model-00003-of-00004.safetensors:  94%|███▊| 4.65G/4.92G [00:54<00:03, 81.4MB/s]
#
#
#
# model-00001-of-00004.safetensors:  93%|███▋| 4.61G/4.98G [00:54<00:04, 83.7MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  92%|███▋| 4.62G/5.00G [00:54<00:04, 90.5MB/s]
#
#
# model-00003-of-00004.safetensors:  95%|███▊| 4.67G/4.92G [00:54<00:02, 92.0MB/s]
#
#
#
# model-00001-of-00004.safetensors:  93%|███▋| 4.63G/4.98G [00:54<00:03, 92.4MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  93%|████▋| 4.65G/5.00G [00:54<00:03, 101MB/s]
#
#
# model-00003-of-00004.safetensors:  95%|████▊| 4.69G/4.92G [00:55<00:02, 103MB/s]
#
#
#
# model-00001-of-00004.safetensors:  94%|████▋| 4.66G/4.98G [00:55<00:03, 104MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  93%|████▋| 4.67G/5.00G [00:55<00:03, 106MB/s]
#
#
# model-00003-of-00004.safetensors:  96%|████▊| 4.71G/4.92G [00:55<00:01, 107MB/s]
#
#
#
# model-00001-of-00004.safetensors:  94%|████▋| 4.68G/4.98G [00:55<00:02, 108MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  94%|████▋| 4.69G/5.00G [00:55<00:02, 111MB/s]
#
#
# model-00003-of-00004.safetensors:  96%|████▊| 4.73G/4.92G [00:55<00:01, 111MB/s]
#
#
#
# model-00001-of-00004.safetensors:  94%|████▋| 4.70G/4.98G [00:55<00:02, 112MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  94%|████▋| 4.71G/5.00G [00:55<00:02, 115MB/s]
#
#
# model-00003-of-00004.safetensors:  97%|████▊| 4.75G/4.92G [00:55<00:01, 115MB/s]
#
#
#
# model-00001-of-00004.safetensors:  95%|████▋| 4.72G/4.98G [00:55<00:02, 113MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  95%|████▋| 4.73G/5.00G [00:55<00:02, 115MB/s]
#
#
# model-00003-of-00004.safetensors:  97%|████▊| 4.77G/4.92G [00:55<00:01, 113MB/s]
#
#
#
# model-00001-of-00004.safetensors:  95%|████▊| 4.74G/4.98G [00:55<00:02, 118MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  95%|████▊| 4.75G/5.00G [00:55<00:02, 122MB/s]
#
#
# model-00003-of-00004.safetensors:  97%|████▊| 4.79G/4.92G [00:55<00:00, 125MB/s]
#
#
#
# model-00001-of-00004.safetensors:  96%|████▊| 4.76G/4.98G [00:55<00:01, 120MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  95%|████▊| 4.77G/5.00G [00:56<00:01, 120MB/s]
#
#
# model-00003-of-00004.safetensors:  98%|████▉| 4.81G/4.92G [00:56<00:00, 125MB/s]
#
#
#
# model-00001-of-00004.safetensors:  96%|████▊| 4.78G/4.98G [00:56<00:01, 122MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  96%|████▊| 4.79G/5.00G [00:56<00:01, 122MB/s]
#
#
# model-00003-of-00004.safetensors:  98%|████▉| 4.83G/4.92G [00:56<00:00, 122MB/s]
#
#
#
# model-00001-of-00004.safetensors:  96%|████▊| 4.80G/4.98G [00:56<00:01, 120MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  96%|████▊| 4.81G/5.00G [00:56<00:01, 123MB/s]
#
#
# model-00003-of-00004.safetensors:  99%|████▉| 4.85G/4.92G [00:56<00:00, 125MB/s]
#
#
#
# model-00001-of-00004.safetensors:  97%|████▊| 4.82G/4.98G [00:56<00:01, 127MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  97%|████▊| 4.83G/5.00G [00:56<00:01, 120MB/s]
#
#
# model-00003-of-00004.safetensors:  99%|████▉| 4.88G/4.92G [00:56<00:00, 123MB/s]
#
#
#
# model-00001-of-00004.safetensors:  97%|████▊| 4.84G/4.98G [00:56<00:01, 123MB/s]
#
#
# model-00003-of-00004.safetensors: 100%|████▉| 4.90G/4.92G [00:56<00:00, 122MB/s]
#
#
#
# model-00001-of-00004.safetensors:  98%|████▉| 4.87G/4.98G [00:56<00:00, 123MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  97%|███▉| 4.85G/5.00G [00:56<00:01, 92.0MB/s]
#
#
# model-00003-of-00004.safetensors: 100%|█████| 4.92G/4.92G [00:56<00:00, 118MB/s]
#
#
#
# model-00003-of-00004.safetensors: 100%|████| 4.92G/4.92G [00:57<00:00, 86.2MB/s]
#
#
#
#
#
# model-00002-of-00004.safetensors:  98%|████▉| 4.88G/5.00G [00:56<00:01, 110MB/s]
#
#
#
# model-00001-of-00004.safetensors:  99%|████▉| 4.91G/4.98G [00:57<00:00, 127MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  98%|████▉| 4.90G/5.00G [00:57<00:00, 123MB/s]
#
#
#
# model-00001-of-00004.safetensors:  99%|████▉| 4.93G/4.98G [00:57<00:00, 126MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  99%|████▉| 4.93G/5.00G [00:57<00:00, 139MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  99%|████▉| 4.95G/5.00G [00:57<00:00, 143MB/s]
#
#
#
# model-00001-of-00004.safetensors:  99%|████▉| 4.95G/4.98G [00:57<00:00, 125MB/s]
#
#
#
#
# model-00002-of-00004.safetensors:  99%|████▉| 4.97G/5.00G [00:57<00:00, 137MB/s]
#
#
#
# model-00001-of-00004.safetensors: 100%|████| 4.98G/4.98G [00:57<00:00, 86.2MB/s]
#
# Fetching 11 files:  27%|██████▊                  | 3/11 [00:57<03:12, 24.09s/it]
#
#
#
#
# model-00002-of-00004.safetensors: 100%|████| 5.00G/5.00G [00:57<00:00, 86.4MB/s]
#
# Fetching 11 files: 100%|████████████████████████| 11/11 [00:58<00:00,  5.28s/it]
# Warmup loader cache: 100%|████████████████████████| 2/2 [01:57<00:00, 58.63s/it]
# Executing graph: 100%|██████████████████████| 1457/1457 [06:01<00:00,  4.03it/s]

# %%
from kaggle_secrets import UserSecretsClient
userSecrets = UserSecretsClient()
HF_WRITE_TOKEN = userSecrets.get_secret("HF_WRITE_TOKEN")

# %%
from huggingface_hub import HfApi

username = "0xVolt"

# Defined in the secrets tab in Kaggle Secrets
api = HfApi(token=HF_WRITE_TOKEN)

api.create_repo(
    repo_id=f"{username}/{MODEL_NAME}",
    repo_type="model"
)

# Push the whole merged-model folder to the hub
api.upload_folder(
    repo_id=f"{username}/{MODEL_NAME}",
    folder_path=OUTPUT_DIR,
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File /opt/conda/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 409 Client Error: Conflict for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[23], line 8
#       5 # Defined in the secrets tab in Kaggle Secrets
#       6 api = HfApi(token=HF_WRITE_TOKEN)
# ----> 8 api.create_repo(
#       9     repo_id=f"{username}/{MODEL_NAME}",
#      10     repo_type="model"
#      11 )
#      13 # Push the whole merged-model folder to the hub
#      14 api.upload_folder(
#      15     repo_id=f"{username}/{MODEL_NAME}",
#      16     folder_path=OUTPUT_DIR,
#      17 )
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:119, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     116 if check_use_auth_token:
#     117     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 119 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/hf_api.py:3360, in HfApi.create_repo(self, repo_id, token, private, repo_type, exist_ok, space_sdk, space_hardware, space_storage, space_sleep_time, space_secrets, space_variables)
#    3357     break
#    3359 try:
# -> 3360     hf_raise_for_status(r)
#    3361 except HTTPError as err:
#    3362     if exist_ok and err.response.status_code == 409:
#    3363         # Repo already exists and `exist_ok=True`
#
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:371, in hf_raise_for_status(response, endpoint_name)
#     367     raise HfHubHTTPError(message, response=response) from e
#     369 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     370 # as well (request id and/or server error message)
# --> 371 raise HfHubHTTPError(str(e), response=response) from e
#
# HfHubHTTPError: 409 Client Error: Conflict for url: https://huggingface.co/api/repos/create (Request ID: Root=1-6649e7c6-04b8eadf19b91db250b52c67;8fb9e508-c301-48ed-9a29-1d25d0489d23)
#
# You already created this model repo
